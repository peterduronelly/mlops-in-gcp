# %%
from google.cloud import bigquery
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !pip install -q pmdarima

# %%
import pmdarima as pm
from pmdarima.model_selection import train_test_split

# %%
bq = bigquery.Client()

# %%
q = """
SELECT * FROM st-data-project.fx_data.eurusd_hourly
"""

# %%
df_fx = bq.query(q).to_dataframe()

df_fx.sort_values(by = 'ts', inplace = True)

# %%
df_fx.plot(x = 'ts', y = 'close')
# Out:
# <Axes: xlabel='ts'>

# %%
# Load/split your data

train, test = train_test_split(df_fx.close.iloc[224:], train_size=6000)

# Fit your model
model = pm.auto_arima(train)

# make your forecasts
forecasts = model.predict(12)  # predict N steps into the future
# Out:
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
new_ts = [df_fx.ts.iloc[-1] + pd.Timedelta(hours = x) for x in range(1,13)]

# %%
new_ts
# Out:
# [Timestamp('2023-09-26 10:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 11:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 12:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 13:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 14:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 15:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 16:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 17:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 18:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 19:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 20:00:00+0000', tz='UTC'),
#  Timestamp('2023-09-26 21:00:00+0000', tz='UTC')]

# %%
plt.plot(df_fx.ts[:6000], df_fx.close[:6000])
plt.plot(df_fx.ts[6000:], df_fx.close[6000:])
plt.plot(new_ts, forecasts, color = 'k', marker = 'o');
# plt.plot(df_fx.close[-300:], color = 'k');

# %%
plt.plot(new_ts, forecasts);

# %%
print(pd.DataFrame({'ts': new_ts, 'close': forecasts}))
# Out:
#                             ts     close
# 6000 2023-09-26 10:00:00+00:00  1.102586
# 6001 2023-09-26 11:00:00+00:00  1.102623
# 6002 2023-09-26 12:00:00+00:00  1.102618
# 6003 2023-09-26 13:00:00+00:00  1.102619
# 6004 2023-09-26 14:00:00+00:00  1.102619
# 6005 2023-09-26 15:00:00+00:00  1.102619
# 6006 2023-09-26 16:00:00+00:00  1.102619
# 6007 2023-09-26 17:00:00+00:00  1.102619
# 6008 2023-09-26 18:00:00+00:00  1.102619
# 6009 2023-09-26 19:00:00+00:00  1.102619
# 6010 2023-09-26 20:00:00+00:00  1.102619
# 6011 2023-09-26 21:00:00+00:00  1.102619
